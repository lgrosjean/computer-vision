# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from mask_rcnn import Mask
# Out:
# Using TensorFlow backend.

# %%
model = Mask()

# %%
import skimage.io

IMG_URL = "https://i.ytimg.com/vi/C-4x4QpmtMs/maxresdefault.jpg"
img = skimage.io.imread(IMG_URL)
skimage.io.imshow(img)
# Out:
# C:\Users\lgrosjean\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\lgrosjean\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
model.mask_detection(img, verbose=1)
# Out:
# elephant , score :  0.99933237
# giraffe , score :  0.9986099
# zebra , score :  0.99807465
# zebra , score :  0.9979436
# zebra , score :  0.99732
# zebra , score :  0.99685895
# giraffe , score :  0.99658257
# zebra , score :  0.9963546
# zebra , score :  0.9953192
# zebra , score :  0.99230134
# zebra , score :  0.9919904
# zebra , score :  0.99173415
# zebra , score :  0.98791134
# zebra , score :  0.9791571
# zebra , score :  0.9782848
# zebra , score :  0.97796226
# zebra , score :  0.9505963
# zebra , score :  0.9140143
# elephant , score :  0.87596786
# bird , score :  0.8190743
# zebra , score :  0.81791675
# horse , score :  0.79939425
# zebra , score :  0.7641583
# zebra , score :  0.7513253

# %%
IMG_URL_2 = "https://www.thesun.co.uk/wp-content/uploads/2016/03/2505426.main_image.jpg"
img_2 = skimage.io.imread(IMG_URL_2)
skimage.io.imshow(img_2)
# Out:
# C:\Users\lgrosjean\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\lgrosjean\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
model.mask_detection(img_2, verbose=0)
